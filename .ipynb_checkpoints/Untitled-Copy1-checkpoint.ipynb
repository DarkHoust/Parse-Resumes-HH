# %% [markdown]
# Project was done by Sultan, Meirzhan, Nurzhahan from SE-2204
# GitHub repository link: https://github.com/DarkHoust/Parse-Resumes-HH.git
# This project is parsing resumes from Head Hunter to find certain CVs.
#
# Briefly description:
#
# 1)With a function "parseResume" which takes the job title.
# 2)With the help of "getLink" we find required CVs.
# 3)After the previous function ,which returns list of links, we parce this links to "parceLink".
# 4)Then every elements of list will be placed in the dictionary "resume".
# 5)You are able to sort CV by every aspects such as age,salary,schedule e.t.d.
# First of all, installing necessary packages:

# %%
# !pip3 install requests
# !pip3 install bs4
# !pip3 install pandas
# !pip3 install csv
# !pip3 install jupyter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Library/Python/3.9/site-packages (2.28.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Python/3.9/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Python/3.9/site-packages (from requests) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Python/3.9/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Python/3.9/site-packages (from requests) (1.26.14)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bs4 in /Library/Python/3.9/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /Library/Python/3.9/site-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /Library/Python/3.9/site-packages (from beautifulsoup4->bs4) (2.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Library/Python/3.9/site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /Library/Python/3.9/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /Library/Python/3.9/site-packages (from pandas) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Python/3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (1.0.0)
# Requirement already satisfied: ipywidgets in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter) (8.0.4)
# Requirement already satisfied: jupyter-console in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter) (6.5.1)
# Requirement already satisfied: nbconvert in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter) (7.2.9)
# Requirement already satisfied: notebook in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter) (6.5.2)
# Requirement already satisfied: qtconsole in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter) (5.4.0)
# Requirement already satisfied: ipykernel in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter) (6.21.2)
# Requirement already satisfied: appnope in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (0.1.3)
# Requirement already satisfied: tornado>=6.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (6.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (0.1.2)
# Requirement already satisfied: nest-asyncio in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (1.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (8.0.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (8.10.0)
# Requirement already satisfied: pyzmq>=20 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (25.0.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (5.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (1.6.6)
# Requirement already satisfied: psutil in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (5.9.4)
# Requirement already satisfied: packaging in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipykernel->jupyter) (23.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipywidgets->jupyter) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipywidgets->jupyter) (3.0.5)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-console->jupyter) (3.0.36)
# Requirement already satisfied: pygments in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-console->jupyter) (2.14.0)
# Requirement already satisfied: beautifulsoup4 in /Library/Python/3.9/site-packages (from nbconvert->jupyter) (4.11.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (2.0.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: defusedxml in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: markupsafe>=2.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (2.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (0.7.2)
# Requirement already satisfied: nbformat>=5.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (5.7.3)
# Requirement already satisfied: tinycss2 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: jinja2>=3.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: bleach in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (6.0.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbconvert->jupyter) (6.0.0)
# Requirement already satisfied: ipython-genutils in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (0.2.0)
# Requirement already satisfied: argon2-cffi in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (0.5.2)
# Requirement already satisfied: prometheus-client in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from notebook->jupyter) (0.16.0)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from qtconsole->jupyter) (2.3.0)
# Requirement already satisfied: zipp>=0.5 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter) (3.14.0)
# Requirement already satisfied: pickleshare in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: stack-data in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.2)
# Requirement already satisfied: decorator in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: backcall in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Python/3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbclassic>=0.4.7->notebook->jupyter) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbclassic>=0.4.7->notebook->jupyter) (2.3.0)
# Requirement already satisfied: fastjsonschema in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.1->nbconvert->jupyter) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from nbformat>=5.1->nbconvert->jupyter) (4.17.3)
# Requirement already satisfied: wcwidth in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.6)
# Requirement already satisfied: ptyprocess in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from terminado>=0.8.3->notebook->jupyter) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Python/3.9/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.4)
# Requirement already satisfied: six>=1.9.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from bleach->nbconvert->jupyter) (1.15.0)
# Requirement already satisfied: webencodings in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (22.2.0)
# Requirement already satisfied: jupyter-server-terminals in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.4.4)
# Requirement already satisfied: websocket-client in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.6.3)
# Requirement already satisfied: cffi>=1.0.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: idna>=2.8 in /Library/Python/3.9/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (1.3.0)
# Requirement already satisfied: pycparser in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (2.0.6)
# Requirement already satisfied: pyyaml>=5.3 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (6.0)
# Requirement already satisfied: rfc3339-validator in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter) (0.1.4)
# Requirement already satisfied: jsonpointer>1.13 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (2.3)
# Requirement already satisfied: isoduration in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (1.12)
# Requirement already satisfied: uri-template in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (1.2.0)
# Requirement already satisfied: fqdn in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/darkhost/Library/Python/3.9/lib/python/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (1.2.3)

# %% [markdown]
# Then importing this packages:

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas
from parser import getLink, parseLink
from csv_config import *
from pandasControl import *

# %% [markdown]
# Test 1:

# %%
dataframe: pandas.DataFrame = pandas.read_csv('node' + '.csv')
sort(dataframe, 'experience_years').head(n=15)
# Out:
#                                                 title  \
# 0                                   Software engineer
# 1                                Frontend-разработчик
# 2   Front end (React | TS) 💻 | Mobile ( React nati...
# 3          Node/Nest.js, Backend developer, Fullstack
# 4                                  Software Developer
# 5                             Программист-разработчик
# 6                                Frontend-разработчик
# 7   Front-end по вене, node назально, pqsql ректально
# 8                                Frontend-разработчик
# 9   Full Stack, NODE JS, разработчик, ArchiMate ар...
# 10            Junior React разработчик, IT специалист
# 11                               Frontend-разработчик
# 12                       инженер по телекоммуникациям
# 13                                  полная занятость"
#
#                       specialization                 salary    age  \
# 0           Программист, разработчик                    NaN     23
# 1                             Другое                    NaN     22
# 2   Специалист технической поддержки                    NaN     22
# 3              Programmer, developer                    NaN     22
# 4           Программист, разработчик                    NaN     25
# 5           Программист, разработчик                    NaN     28
# 6           Программист, разработчик      2 500 USD на руки     30
# 7     Руководитель группы разработки      3 600 USD на руки     25
# 8           Программист, разработчик                    NaN     29
# 9           Программист, разработчик  2 764 000 KZT на руки     33
# 10          Программист, разработчик                    NaN     32
# 11          Программист, разработчик                    NaN     34
# 12           Инженер по эксплуатации    300 000 KZT на руки     43
# 13                                 2                     10  False
#
#                                            employment  experience_years  \
# 0                        стажировка, полная занятость               1.0
# 1   стажировка, частичная занятость, полная занятость               1.0
# 2   частичная занятость, проектная работа, полная ...               2.0
# 3                  project work, part time, full time               3.0
# 4   проектная работа, стажировка, частичная занято...               3.0
# 5                                    полная занятость               4.0
# 6                                    полная занятость               6.0
# 7   проектная работа, частичная занятость, полная ...               6.0
# 8               частичная занятость, полная занятость               8.0
# 9   стажировка, волонтерство, частичная занятость,...               9.0
# 10  проектная работа, частичная занятость, полная ...              10.0
# 11  частичная занятость, проектная работа, полная ...              10.0
# 12                                   полная занятость              20.0
# 13  https://hh.kz/resume/e6be9ffe00087d79960039ed1...               NaN
#
#     experience_months    sex  \
# 0                 3.0  False
# 1                11.0  False
# 2                 6.0  False
# 3                 2.0   True
# 4                 9.0  False
# 5                 9.0  False
# 6                 8.0  False
# 7                10.0  False
# 8                 6.0  False
# 9                 0.0  False
# 10                6.0  False
# 11               11.0  False
# 12                7.0  False
# 13                NaN    NaN
#
#                                                  link
# 0   https://hh.kz/resume/bd1465da0008aca84b0039ed1...
# 1   https://hh.kz/resume/faedb5620007af1b560039ed1...
# 2   https://hh.kz/resume/4afdf6960008931f290039ed1...
# 3   https://hh.kz/resume/adf577e500092bc7f80039ed1...
# 4   https://hh.kz/resume/27ecf7a80007e6de260039ed1...
# 5   https://hh.kz/resume/cf97790a0002f0a0d70039ed1...
# 6   https://hh.kz/resume/68643c050003a934820039ed1...
# 7   https://hh.kz/resume/5671d08e000599e3fc0039ed1...
# 8   https://hh.kz/resume/0db1d7c00002336f550039ed1...
# 9   https://hh.kz/resume/79b0be5800018cdf4a0039ed1...
# 10  https://hh.kz/resume/f194620500020704660039ed1...
# 11  https://hh.kz/resume/485e00ef0005f3ae590039ed1...
# 12  https://hh.kz/resume/0354d1330000dc73ea0039ed1...
# 13                                                NaN
